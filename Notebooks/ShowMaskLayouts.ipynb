# %%
# %matplotlib notebook

import sys
import logging
import matplotlib.pyplot as plt
import numpy as np

sys.path.append("../DesignTool")
from smdtLibs.configFile import ConfigFile
from targets import TargetList
from smdtLibs.inOutChecker import InOutChecker
from maskLayouts import MaskLayouts, shrinkMask, BadColumns, GuiderFOVs
from smdtLibs import utils, drawUtils

# %%
# %load_ext nb_black

# %%
keys = MaskLayouts.keys()

# %%
print(keys)
# Out:
# dict_keys(['deimos', 'deimos_plain', 'deimos_no_gap', 'lris'])

# %%
plt.figure(figsize=(11, 4))
plt.gca().set_aspect("equal")

# Plot the mask layout

# drawUtils.drawPatch(plt.gca(), MaskLayouts["deimos1"], fc="None", ec="r").set_label(
#    "Layout"
# )

drawUtils.drawPatch(plt.gca(), MaskLayouts["deimos"], fc="None", ec="b").set_label(
    "Layout"
)
drawUtils.drawPatch(plt.gca(), b, fc="None", ec="r").set_label("Layout")
drawUtils.drawPatch(
    plt.gca(), MaskLayouts["deimos_plain"], fc="None", ec="g"
).set_label("Layout")

drawUtils.drawPatch(plt.gca(), BadColumns["deimos"], fc="None", ec="y").set_label("xx")

# drawUtils.drawPatch(plt.gca(), BadColumns["deimos"], fc='None', ec='y').set_label('Bad columns')
drawUtils.drawPatch(plt.gca(), GuiderFOVs["deimos"], fc="None", ec="b").set_label(
    "Guider"
)

plt.xlim(-600, 600)
plt.ylim(150, 500)
# plt.legend(bbox_to_anchor=(1.25, 1), loc="upper right")
plt.grid()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1100">

# %%
a = [[248, 192], [248, 478], [247, 192], [247, 482]]
b = [[246, 145], [246, -143], [251, 143], [249, -147]]

# %%
a = MaskLayouts["deimos"]

# %%
b = np.array(a) * [-1, 1, 1]
